# %%
# Facial Recognition App:-

! pip install face-recognition
! pip install cmake
! pip install opencv-python
! pip install numpy as np
# Out:
# ...
#   Using cached face_recognition-1.3.0-py2.py3-none-any.whl (15 kB)
# ...
#   Using cached face_recognition_models-0.3.0.tar.gz (100.1 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ---------------------------------------- 0.0/11.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.8 MB ? eta -:--:--
#      --------------------------------------- 0.0/11.8 MB 262.6 kB/s eta 0:00:45
#      --------------------------------------- 0.1/11.8 MB 469.7 kB/s eta 0:00:25
#       --------------------------------------- 0.2/11.8 MB 1.1 MB/s eta 0:00:11
#      - -------------------------------------- 0.4/11.8 MB 1.6 MB/s eta 0:00:07
#      - -------------------------------------- 0.5/11.8 MB 2.0 MB/s eta 0:00:06
#      -- ------------------------------------- 0.7/11.8 MB 2.4 MB/s eta 0:00:05
#      --- ------------------------------------ 1.0/11.8 MB 2.7 MB/s eta 0:00:05
# ...

# %%
import face_recognition
import cv2
import numpy as np
import csv
from datetime import datetime

video_capture =cv2.VideoCapture(0)

# Load known faces:
akash_image = face_recognition.load_image_file("faces/akash.jpg")
akash_encoding = face_recognition.face_encodings(harrys_image)[0]

parth_image = face_recognition.load_image_file("faces/parth.jpg")
parth_encoding = face_recognition.face_encodings(parth_image)[0]

aanya_image = face_recognition.load_image_file("faces/aanya.jpg")
aanya_encoding = face_recognition.face_encodings(aanya_image)[0]


known_face_encodings = [akash_encoding, parth_encoding, aanya_encoding]
known_face_names = ["Akash","Parth", "Aanaya"]

# List of family members:
family_members = known_face_names.copy()

face_locations = []
face_encodings = []

# Get the current Date and Time:
now = datetime.now()
current_date = datetime.strftime("%Y-%m-%d")

f = open(f"{current_date}.csv", "w+", newline="")
lnwriter = csv.writer(f)

while True:
    _, frame = video_capture.read()
    small_frame = cv2.resize(frame, (0,0), fx=0.25, fy=0.25)
    rgbsmall_frame = cv2.cvtColor(small_frame, cv2.COLOR_BGR2RGB)
    
    #Recognizes Faces
    face_locations = face_recognition.face_locations(rgb_small_frame)
    face_encodings = face_recognition.face_encodings(rgb_small_frame, face_locations)
    
    for face_encodings in face_encodings:
        matches = face_recognition.compare_faces(known_face_encodings, face_encoding)
        face_distance = face_recognition.face_distance(known_face_encodings,face_encoding)
        best_match_index = np.argmin(face_distance)
        
        if (matches[best_matcch_index]):
            name = known_face_names[best_match_index]
            
        # Add the text if the person is present:
        if name in know_face_names:
            font = cv2.FONT_HERSHEY_SIMPLEX
            bottomLeftCornerOfText = (10, 100)
            fontScale = 1.5
            fontColor = (255, 0, 0)
            thickness = 3
            lineType = 2
            cv2.putText(frame, name + "Present", bottomLeftCornerOfText, font, fontScale, fontColor, thickness, linkType)
            
            if name in family_members:
                family_members.remove(name)
                current_time = now.strftime("%H-%M%S")
                lnwriter.writerow([name, current_time])
            
    cv2.imshow("Cheese", frame)
    if cv2.waitkey(1) & 0xff == ord("q"):
        break

videos_capture.release()
cv2.destroyAllWindows()
f.close()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import face_recognition
#       2 import cv2
#       3 import numpy as np
#
# ModuleNotFoundError: No module named 'face_recognition'
